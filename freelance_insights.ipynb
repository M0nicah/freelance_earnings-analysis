# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("freelancer_earnings_bd.csv")
data.head(5)
# Out:
#    Freelancer_ID       Job_Category       Platform Experience_Level  \
# 0              1    Web Development         Fiverr         Beginner
# 1              2    App Development         Fiverr         Beginner
# 2              3    Web Development         Fiverr         Beginner
# 3              4         Data Entry  PeoplePerHour     Intermediate
# 4              5  Digital Marketing         Upwork           Expert
#
#   Client_Region  Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  \
# 0          Asia  Mobile Banking            180          1620        95.79
# 1     Australia  Mobile Banking            218          9078        86.38
# 2            UK          Crypto             27          3455        85.17
# 3          Asia   Bank Transfer             17          5577        14.37
# 4          Asia          Crypto            245          5898        99.37
#
#    Job_Success_Rate  Client_Rating  Job_Duration_Days Project_Type  \
# 0             68.73           3.18                  1        Fixed
# 1             97.54           3.44                 54        Fixed
# 2             86.60           4.20                 46       Hourly
# 3             79.93           4.47                 41       Hourly
# 4             57.80           5.00                 41       Hourly
#
#    Rehire_Rate  Marketing_Spend
# 0        40.19               53
# 1        36.53              486
# 2        74.05              489
# 3        27.58               67
# 4        69.09              489

# %%
data.columns
# Out:
# Index(['Freelancer_ID', 'Job_Category', 'Platform', 'Experience_Level',
#        'Client_Region', 'Payment_Method', 'Job_Completed', 'Earnings_USD',
#        'Hourly_Rate', 'Job_Success_Rate', 'Client_Rating', 'Job_Duration_Days',
#        'Project_Type', 'Rehire_Rate', 'Marketing_Spend'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Freelancer_ID        0
# Job_Category         0
# Platform             0
# Experience_Level     0
# Client_Region        0
# Payment_Method       0
# Job_Completed        0
# Earnings_USD         0
# Hourly_Rate          0
# Job_Success_Rate     0
# Client_Rating        0
# Job_Duration_Days    0
# Project_Type         0
# Rehire_Rate          0
# Marketing_Spend      0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Freelancer_ID        0
# Job_Category         0
# Platform             0
# Experience_Level     0
# Client_Region        0
# Payment_Method       0
# Job_Completed        0
# Earnings_USD         0
# Hourly_Rate          0
# Job_Success_Rate     0
# Client_Rating        0
# Job_Duration_Days    0
# Project_Type         0
# Rehire_Rate          0
# Marketing_Spend      0
# dtype: int64

# %%
data.isnull().values.any()
# Out:
# np.False_

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe(include="all")
# Out:
#         Freelancer_ID    Job_Category Platform Experience_Level Client_Region  \
# count     1950.000000            1950     1950             1950          1950
# unique            NaN               8        5                3             7
# top               NaN  Graphic Design   Upwork         Beginner     Australia
# freq              NaN             265      420              668           298
# mean       975.500000             NaN      NaN              NaN           NaN
# std        563.060832             NaN      NaN              NaN           NaN
# min          1.000000             NaN      NaN              NaN           NaN
# 25%        488.250000             NaN      NaN              NaN           NaN
# 50%        975.500000             NaN      NaN              NaN           NaN
# 75%       1462.750000             NaN      NaN              NaN           NaN
# max       1950.000000             NaN      NaN              NaN           NaN
#
#        Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  \
# count            1950    1950.000000   1950.000000  1950.000000
# unique              4            NaN           NaN          NaN
# top            Crypto            NaN           NaN          NaN
# freq              514            NaN           NaN          NaN
# mean              NaN     150.864103   5017.566667    52.579774
# std               NaN      85.480770   2926.279918    26.927584
# min               NaN       5.000000     51.000000     5.020000
# 25%               NaN      76.000000   2419.000000    30.047500
# 50%               NaN     149.000000   5048.000000    52.285000
# 75%               NaN     225.000000   7608.250000    75.125000
# max               NaN     299.000000   9991.000000    99.830000
#
#         Job_Success_Rate  Client_Rating  Job_Duration_Days Project_Type  \
# count        1950.000000    1950.000000        1950.000000         1950
# unique               NaN            NaN                NaN            2
# top                  NaN            NaN                NaN        Fixed
# freq                 NaN            NaN                NaN          997
# mean           74.951846       3.995892          44.704615          NaN
# std            14.615735       0.575976          26.022998          NaN
# min            50.160000       3.000000           1.000000          NaN
# 25%            61.917500       3.510000          22.000000          NaN
# 50%            75.400000       3.990000          45.000000          NaN
# 75%            87.537500       4.500000          67.000000          NaN
# max            99.990000       5.000000          89.000000          NaN
#
#         Rehire_Rate  Marketing_Spend
# count   1950.000000      1950.000000
# unique          NaN              NaN
# top             NaN              NaN
# freq            NaN              NaN
# mean      44.556913       248.517436
# std       20.193842       148.084581
# min       10.000000         0.000000
# 25%       27.150000       119.000000
# 50%       43.920000       252.500000
# 75%       61.690000       379.000000
# max       79.950000       499.000000

# %%
#duplicate rows
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Freelancer_ID, Job_Category, Platform, Experience_Level, Client_Region, Payment_Method, Job_Completed, Earnings_USD, Hourly_Rate, Job_Success_Rate, Client_Rating, Job_Duration_Days, Project_Type, Rehire_Rate, Marketing_Spend]
# Index: []

# %%
data.head()
# Out:
#    Freelancer_ID       Job_Category       Platform Experience_Level  \
# 0              1    Web Development         Fiverr         Beginner
# 1              2    App Development         Fiverr         Beginner
# 2              3    Web Development         Fiverr         Beginner
# 3              4         Data Entry  PeoplePerHour     Intermediate
# 4              5  Digital Marketing         Upwork           Expert
#
#   Client_Region  Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  \
# 0          Asia  Mobile Banking            180          1620        95.79
# 1     Australia  Mobile Banking            218          9078        86.38
# 2            UK          Crypto             27          3455        85.17
# 3          Asia   Bank Transfer             17          5577        14.37
# 4          Asia          Crypto            245          5898        99.37
#
#    Job_Success_Rate  Client_Rating  Job_Duration_Days Project_Type  \
# 0             68.73           3.18                  1        Fixed
# 1             97.54           3.44                 54        Fixed
# 2             86.60           4.20                 46       Hourly
# 3             79.93           4.47                 41       Hourly
# 4             57.80           5.00                 41       Hourly
#
#    Rehire_Rate  Marketing_Spend
# 0        40.19               53
# 1        36.53              486
# 2        74.05              489
# 3        27.58               67
# 4        69.09              489

# %%
data['Earnings_per_job'] = (data["Earnings_USD"]/ data['Job_Completed']).round(2)

# %%
data.head()
# Out:
#    Freelancer_ID       Job_Category       Platform Experience_Level  \
# 0              1    Web Development         Fiverr         Beginner
# 1              2    App Development         Fiverr         Beginner
# 2              3    Web Development         Fiverr         Beginner
# 3              4         Data Entry  PeoplePerHour     Intermediate
# 4              5  Digital Marketing         Upwork           Expert
#
#   Client_Region  Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  \
# 0          Asia  Mobile Banking            180          1620        95.79
# 1     Australia  Mobile Banking            218          9078        86.38
# 2            UK          Crypto             27          3455        85.17
# 3          Asia   Bank Transfer             17          5577        14.37
# 4          Asia          Crypto            245          5898        99.37
#
#    Job_Success_Rate  Client_Rating  Job_Duration_Days Project_Type  \
# 0             68.73           3.18                  1        Fixed
# 1             97.54           3.44                 54        Fixed
# 2             86.60           4.20                 46       Hourly
# 3             79.93           4.47                 41       Hourly
# 4             57.80           5.00                 41       Hourly
#
#    Rehire_Rate  Marketing_Spend  Earnings_per_job
# 0        40.19               53              9.00
# 1        36.53              486             41.64
# 2        74.05              489            127.96
# 3        27.58               67            328.06
# 4        69.09              489             24.07

# %%
#selecting the top earners
top_earners = data.sort_values(by='Earnings_USD', ascending=False)
top_earners.head(10)
# Out:
#       Freelancer_ID       Job_Category       Platform Experience_Level  \
# 597             598    Web Development  PeoplePerHour     Intermediate
# 879             880    Web Development         Fiverr     Intermediate
# 1399           1400         Data Entry  PeoplePerHour         Beginner
# 636             637    Content Writing         Fiverr           Expert
# 267             268         Data Entry  PeoplePerHour         Beginner
# 592             593     Graphic Design  PeoplePerHour     Intermediate
# 590             591    App Development         Upwork     Intermediate
# 892             893  Digital Marketing         Upwork         Beginner
# 303             304    Content Writing         Fiverr     Intermediate
# 467             468   Customer Support         Fiverr     Intermediate
#
#      Client_Region  Payment_Method  Job_Completed  Earnings_USD  Hourly_Rate  \
# 597         Canada   Bank Transfer            196          9991        32.64
# 879             UK          PayPal            273          9988        32.85
# 1399   Middle East          Crypto            290          9984        66.80
# 636           Asia  Mobile Banking             23          9981        41.42
# 267           Asia          Crypto              5          9975        98.76
# 592         Canada          PayPal            278          9974        63.39
# 590             UK   Bank Transfer            277          9973        20.24
# 892         Canada          Crypto             15          9972        54.57
# 303             UK  Mobile Banking            198          9967        25.57
# 467    Middle East  Mobile Banking             37          9964        93.24
#
#       Job_Success_Rate  Client_Rating  Job_Duration_Days Project_Type  \
# 597              58.62           3.82                 57       Hourly
# 879              61.10           3.06                 84       Hourly
# 1399             85.34           3.48                 10       Hourly
# 636              76.63           3.14                 23        Fixed
# 267              85.12           3.56                 57       Hourly
# 592              59.09           4.69                 56       Hourly
# 590              56.94           4.32                 70        Fixed
# 892              91.51           4.84                 80        Fixed
# 303              81.87           4.66                 17        Fixed
# 467              93.43           3.08                 71        Fixed
#
#       Rehire_Rate  Marketing_Spend  Earnings_per_job
# 597         19.32               16             50.97
# 879         26.35               65             36.59
# 1399        11.90              371             34.43
# 636         39.85              390            433.96
# 267         16.65               38           1995.00
# 592         49.72              343             35.88
# 590         28.28              127             36.00
# 892         14.22              206            664.80
# 303         77.44              343             50.34
# 467         40.93              420            269.30

# %%
top_earners_selected=top_earners[["Freelancer_ID", 'Experience_Level', "Earnings_USD", "Job_Category", "Job_Completed", "Platform"]]
top_earners_selected.head()
# Out:
#       Freelancer_ID Experience_Level  Earnings_USD     Job_Category  \
# 597             598     Intermediate          9991  Web Development
# 879             880     Intermediate          9988  Web Development
# 1399           1400         Beginner          9984       Data Entry
# 636             637           Expert          9981  Content Writing
# 267             268         Beginner          9975       Data Entry
#
#       Job_Completed       Platform
# 597             196  PeoplePerHour
# 879             273         Fiverr
# 1399            290  PeoplePerHour
# 636              23         Fiverr
# 267               5  PeoplePerHour

# %%
#top category by earnings
top_categories= (data.groupby("Job_Category")['Earnings_USD']
.sum()
.sort_values(ascending=False)
.reset_index())
top_categories.columns = ["Job_Category", "Total_Earnings_USD"]
top_categories.head()
# Out:
#        Job_Category  Total_Earnings_USD
# 0    Graphic Design             1361271
# 1   App Development             1289959
# 2  Customer Support             1253071
# 3   Web Development             1251366
# 4        Data Entry             1209294

# %%
#top earning platforms
top_platforms = (data.groupby("Platform")["Earnings_USD"]
                 .sum()
                 .sort_values(ascending=False)
                 .reset_index())

top_platforms.columns = ["Platform", "Total_Earnings_USD"]
top_platforms.head()
# Out:
#         Platform  Total_Earnings_USD
# 0         Upwork             2112162
# 1         Fiverr             1981479
# 2     Freelancer             1945159
# 3         Toptal             1944435
# 4  PeoplePerHour             1801020

# %%
#Average Hourly Rate by Experience Level
avg_rate_by_experience = (data.groupby("Experience_Level")
              .agg(
                  avg_hourly_rate = ("Hourly_Rate", 'mean')
                  
              )
                .round(2)
                .sort_values(by='avg_hourly_rate', ascending=False)
                .reset_index()
              )
avg_rate_by_experience.columns=["Experience_Level", "Average_Rate"]

avg_rate_by_experience.head()
# Out:
#   Experience_Level  Average_Rate
# 0     Intermediate         54.43
# 1           Expert         52.42
# 2         Beginner         50.96

# %%
#platforms with highest average earnings and success rates.
avg_earnings_and_success_rate = (data.groupby("Platform")
                                    .agg(
                                     avg_earnings = ("Earnings_USD", 'mean'),
                                     avg_success_rate = ("Job_Success_Rate", 'mean')
                                    )
                                    .round(2)
                                    .sort_values(by="avg_earnings", ascending=False)
                                    .reset_index()
                                )
avg_earnings_and_success_rate.columns = ["Platforms", "Average_Earnings", "Average_Success_Rate"]
avg_earnings_and_success_rate.head()
# Out:
#        Platforms  Average_Earnings  Average_Success_Rate
# 0         Fiverr           5067.72                 75.10
# 1     Freelancer           5039.27                 75.69
# 2  PeoplePerHour           5030.78                 74.72
# 3         Upwork           5028.96                 74.02
# 4         Toptal           4922.62                 75.28

# %%
#how client ratings vary by region or payment method
client_rating_by_region = (data.groupby(["Client_Region", "Payment_Method"])
                           .agg(
                               avg_rating = ("Client_Rating", "mean")
                           )
                           .round(2)
                           .sort_values(by="avg_rating", ascending=False)
                           .reset_index()
                           )
client_rating_by_region.columns=["Client_Region", "Payment_Method", "Average_Rating"]
client_rating_by_region.head(10)
# Out:
#   Client_Region  Payment_Method  Average_Rating
# 0           USA   Bank Transfer            4.22
# 1     Australia          Crypto            4.10
# 2   Middle East   Bank Transfer            4.09
# 3           USA          PayPal            4.07
# 4   Middle East          Crypto            4.07
# 5        Canada          PayPal            4.05
# 6           USA  Mobile Banking            4.04
# 7        Canada   Bank Transfer            4.03
# 8        Europe   Bank Transfer            4.03
# 9   Middle East          PayPal            4.01

# %%
##how client ratings vary by payment method
client_rating_by_payment_method = (data.groupby("Payment_Method")
                           .agg(
                               avg_rating = ("Client_Rating", "mean")
                           )
                           .round(2)
                           .sort_values(by="avg_rating", ascending=False)
                           .reset_index()
                           )
client_rating_by_payment_method.columns=["Payment_Method", "Average_Rating"]
client_rating_by_payment_method.head()
# Out:
#    Payment_Method  Average_Rating
# 0   Bank Transfer            4.03
# 1          PayPal            4.01
# 2          Crypto            3.98
# 3  Mobile Banking            3.97

# %%
#Are expert freelancers significantly more successful in terms of earnings or ratings than beginners or intermediates?

expert_success = (data.groupby("Experience_Level")
                  .agg(
                      total_earnings=("Earnings_USD", "sum"),
                      avg_rating = ("Client_Rating", "mean")
                  )
                  .round(2)
                  .sort_values(by="avg_rating", ascending=False)
                  .reset_index()
                  
                  )
expert_success.columns =["Experience_Level", "Total_Earnings", "Average_Rating"]
expert_success.head()

# no, experts are only significantly successfull than beginners in terms of success rate and earnings
# Out:
#   Experience_Level  Total_Earnings  Average_Rating
# 0     Intermediate         3376655            4.02
# 1           Expert         3112564            3.99
# 2         Beginner         3295036            3.98

# %%
#Rehire Rate Trends by Client Region
data.groupby('Client_Region')['Rehire_Rate'].mean().round(2).reset_index().sort_values(by='Rehire_Rate', ascending=False).head(10)
# Out:
#   Client_Region  Rehire_Rate
# 5            UK        46.40
# 2        Canada        45.15
# 1     Australia        44.88
# 6           USA        44.41
# 4   Middle East        44.26
# 3        Europe        43.94
# 0          Asia        42.89

# %%
#plotting top platforms

plt.figure(figsize=(10,6))
sns.barplot(data=top_platforms, x="Platform", y="Total_Earnings_USD",hue="Platform", palette="twilight")
plt.title = ("Top Platforms")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# plotting average earnings
plt.figure(figsize=(9,5))
sns.barplot(data=avg_earnings_and_success_rate, x="Platforms", y="Average_Earnings", palette="twilight")
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/wl/800g4xyd41341dytw82t3c7w0000gn/T/ipykernel_14749/2476533209.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_earnings_and_success_rate, x="Platforms", y="Average_Earnings", palette="twilight")

# %%
#plotting average hourly rate
plt.figure(figsize=(5,6))
sns.barplot(data=avg_rate_by_experience, x="Experience_Level", y="Average_Rate", hue="Platform", palette="twilight")
plt.show()

# %%
#spread & skew in freelancer income.
sns.histplot(data['Earnings_USD'], bins=30, kde=True)
plt.show()

# %%
#plotting client
sns.barplot(data=data, x='Client_Region', y='Rehire_Rate', estimator='mean', hue="Platform", palette="twilight")
plt.xticks(rotation=45)

# %%
#relationship btwn Success Rate & Client Rating colored by experience level
plt.figure(figsize=(10,5))
sns.scatterplot(data=data, x='Job_Success_Rate', y='Client_Rating', hue="Experience_Level")

# %%
#Hourly vs Fixed Projects: Earnings Comparison
sns.boxplot(data=data, x='Project_Type', y='Earnings_USD')

# %%
#Count Plot: Projects by Client Region
sns.countplot(data=data, x='Client_Region', hue="Platform", palette="twilight")

# %%
#Scatter Plot: Marketing Spend vs Earnings to Test if high spend leads to more income.
plt.figure(figsize=(10,6))
sns.scatterplot(data=data, x='Marketing_Spend', y='Earnings_USD', hue='Platform')

# %%
#plot top job categories
plt.figure(figsize=(10,6))
sns.barplot(data=top_categories, x='Job_Category', y='Total_Earnings_USD', hue="Platform",  palette="twilight")
plt.xticks(rotation=30)

# %%
voila freelance_insights.ipynb
